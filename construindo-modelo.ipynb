# %%
import pandas as pd
import numpy as np
from warnings import filterwarnings
from sklearn.metrics import roc_auc_score, average_precision_score, log_loss
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from lightgbm import LGBMClassifier
from skopt import forest_minimize
import joblib as jb

pd.options.display.max_columns = 999
pd.options.display.max_rows = 999
filterwarnings('ignore')

# %% [markdown]
# <h2>Índice</h2>
# <font size=3>
# <ol>
#     <li><a href='#PRE'>Pré-processamento</a></li>
#     <li><a href='#MODEL'>Modelo</a></li>
#     <ul>
#         <li><a href='#LR'>Regressão Logística</a></li>
#         <li><a href='#RF'>Random Forest</a></li>
#         <li><a href='#LGBM'>LightGBM</a></li>
#         <li><a href='#ENSEN'>Ensemble</a></li>
#     </ul>
#     <li><a href='#SAV'>Salvando os modelos</a></li>
# </ol>
# </font>
#
# <a name='PRE'></a>
# <h2>Pré-processamento</h2>
# <h3>Carregando o dataset</h3>

# %%
df = pd.read_csv('apartamentos.csv')
df.drop(['endereco', 'update_time', 'apartment_link', 'id'], axis=1, inplace=True)
df.head()
# Out:
#    y  quartos  area  custo  vagas  mobiliado             bairro   latitude  \
# 0  0        2    80   3455      1          0      Vila Madalena -23.540695
# 1  0        3   120   5975      1          0  Alto de Pinheiros -23.544324
# 2  0        2    68   3390      1          0  Alto de Pinheiros -23.540833
# 3  0        3    88   5188      2          0      Vila Madalena -23.541757
# 4  0        2    52   2289      0          1  Alto de Pinheiros -23.542408
#
#    longitude        estacao  distancia  linha_amarela  linha_azul  \
# 0 -46.701796  Vila Madalena       1.26              0           0
# 1 -46.709045  Vila Madalena       1.85              0           0
# 2 -46.706647  Vila Madalena       1.70              0           0
# 3 -46.701762  Vila Madalena       1.21              0           0
# 4 -46.716614  Vila Madalena       2.64              0           0
#
#    linha_lilas  linha_prata  linha_verde  linha_vermelha
# 0            0            0            1               0
# 1            0            0            1               0
# 2            0            0            1               0
# 3            0            0            1               0
# 4            0            0            1               0

# %% [markdown]
# <font size=3>Dividindo entre X e y.</font>

# %%
X = df.drop('y', axis=1)
y = df['y']
print('X: {}\ny: {}'.format(X.shape, y.shape))
# Out:
# X: (6538, 16)
# y: (6538,)

# %% [markdown]
# <font size=3><br>Dividindo entre treino e teste.</font>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=75)
print('X_train:{} \ny_train:{} \nX_test:\t{} \ny_test:\t{}'.format(X_train.shape,y_train.shape,X_test.shape,y_test.shape))
# Out:
# X_train:(4576, 16)
# y_train:(4576,)
# X_test:	(1962, 16)
# y_test:	(1962,)

# %%
X_train.head()
# Out:
#       quartos  area  custo  vagas  mobiliado           bairro   latitude  \
# 2273        1    33   5504      1          1       Consolação -23.550440
# 1041        1    34   4145      2          1       Bela Vista -23.567636
# 1318        2   104   3414      0          0    Santa Cecília -23.538508
# 2247        1    45   3826      1          0       Bela Vista -23.561625
# 2265        2   110   4945      1          0  Jardim Paulista -23.567925
#
#       longitude                 estacao  distancia  linha_amarela  linha_azul  \
# 2273 -46.654623  Higienopolis Mackenzie       0.29              1           0
# 1041 -46.646206              Brigadeiro       0.28              0           0
# 1318 -46.645741           Santa Cecilia       0.34              0           0
# 2247 -46.650809            Trianon Masp       0.38              0           0
# 2265 -46.656107            Trianon Masp       0.53              0           0
#
#       linha_lilas  linha_prata  linha_verde  linha_vermelha
# 2273            0            0            0               0
# 1041            0            0            1               0
# 1318            0            0            0               1
# 2247            0            0            1               0
# 2265            0            0            1               0

# %% [markdown]
# <font size=3>
#     Com <i>OneHotEncoder</i> vamos transformar as variáveis <i>bairro</i> e <i>estacao</i> para númericas para que possamos utilizar nos nossos modelos.
# </font>

# %%
cat_cols = ['bairro', 'estacao']
enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
train_cat_feat = enc.fit_transform(X_train[cat_cols])
train_cat_feat = pd.DataFrame(train_cat_feat)
# train_cat_feat.columns = enc.get_feature_names(cat_cols)
train_cat_feat.index = X_train.index
train_num_feat = X_train.drop(cat_cols, axis=1)
X_train_feat = pd.merge(train_num_feat, train_cat_feat, left_index=True, right_index=True)

# %% [markdown]
# <font size=3>Replicando para os dados de teste.</font>

# %%
test_cat_feat = enc.transform(X_test[cat_cols])
test_cat_feat = pd.DataFrame(test_cat_feat)
# test_cat_feat.columns = enc.get_feature_names(cat_cols)
test_cat_feat.index = X_test.index
test_num_feat = X_test.drop(cat_cols, axis=1)
X_test_feat = pd.merge(test_num_feat, test_cat_feat, left_index=True, right_index=True)

# %% [markdown]
# <a name='MODEL'></a>
# <h2>Modelo</h2>
#
# <a name='LR'></a>
# <h3>Regressão Logística</h3>

# %%
lr = LogisticRegression(random_state=75)
lr.fit(X_train_feat, y_train)
ypred_lr = lr.predict_proba(X_test_feat)[:,1]

# %%
print('average precision score: {}'.format(average_precision_score(y_test, ypred_lr)))
print('roc_auc_scode: {}'.format(roc_auc_score(y_test, ypred_lr)))
print('log loss: {}'.format(log_loss(y_test, ypred_lr)))
# Out:
# average precision score: 0.16968485627904073
# roc_auc_scode: 0.9421481706120556
# log loss: 0.060769089723026894

# %% [markdown]
# <a name='RF'></a>
# <h3>Random Forest</h3>

# %%
rf = RandomForestClassifier(n_estimators=1000, random_state=75, min_samples_leaf=2, class_weight='balanced')
rf.fit(X_train_feat, y_train)
ypred_rf = rf.predict_proba(X_test_feat)[:,1]

# %%
print('average precision score: {}'.format(average_precision_score(y_test, ypred_rf)))
print('roc_auc_scode: {}'.format(roc_auc_score(y_test, ypred_rf)))
print('log loss: {}'.format(log_loss(y_test, ypred_rf)))
# Out:
# average precision score: 0.5485563211695972
# roc_auc_scode: 0.9908486005316017
# log loss: 0.04966813134187631

# %% [markdown]
# <a name='LGBM'></a>
# <h3>LightGBM</h3>

# %%
def tune_lgbm(params):
    print(params)
    lr = params[0]
    max_depth = params[1]
    min_child_samples = params[2]
    subsample = params[3]
    colsample_bytree = params[4]
    n_estimators = params[5]
    
    lgbm = LGBMClassifier(learning_rate=lr, num_leaves=2 ** max_depth, max_depth=max_depth, 
                          min_child_samples=min_child_samples, subsample=subsample,
                          colsample_bytree=colsample_bytree, bagging_freq=1,n_estimators=n_estimators, random_state=0, 
                          class_weight="balanced", n_jobs=6)
    lgbm.fit(X_train_feat, y_train)
    
    ypred_lgbm = lgbm.predict_proba(X_test_feat)[:,1]
    
    print(roc_auc_score(y_test, ypred_lgbm))
    
    return -average_precision_score(y_test, ypred_lgbm)

space = [(1e-3, 1e-1, 'log-uniform'), # lr
          (1, 15), # max_depth
          (1, 20), # min_child_samples
          (0.05, 1.), # subsample
          (0.05, 1.), # colsample_bytree
          (100,1000)] # n_estimators

res = forest_minimize(tune_lgbm, space, random_state=75, n_random_starts=20, n_calls=50, verbose=1)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# [0.026573581158061813, 2, 9, 0.3602419777451103, 0.38907875080188686, 949]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9884581764989206
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.5741
# Function value obtained: -0.4831
# Current minimum: -0.4831
# Iteration No: 2 started. Evaluating function at random point.
# [0.01226172672492125, 8, 7, 0.4054213799661132, 0.9369030598583269, 337]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9917227108122091
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 1.8359
# Function value obtained: -0.5466
# Current minimum: -0.5466
# Iteration No: 3 started. Evaluating function at random point.
# [0.01683319796246901, 5, 5, 0.7513238533324651, 0.631305640343713, 568]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9899209732950389
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 1.1757
# Function value obtained: -0.5167
# Current minimum: -0.5466
# Iteration No: 4 started. Evaluating function at random point.
# [0.003248394018273504, 13, 11, 0.6324068503439444, 0.4933551902972303, 798]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9907950835756463
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 17.7101
# Function value obtained: -0.5283
# Current minimum: -0.5466
# Iteration No: 5 started. Evaluating function at random point.
# [0.09950875018385262, 4, 11, 0.25968542451998294, 0.3145303042573581, 465]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9820539807695738
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.5429
# Function value obtained: -0.3950
# Current minimum: -0.5466
# Iteration No: 6 started. Evaluating function at random point.
# [0.002146135513454552, 12, 2, 0.9553069736885443, 0.4361323097642947, 763]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.990063685177587
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 54.5495
# Function value obtained: -0.5439
# Current minimum: -0.5466
# Iteration No: 7 started. Evaluating function at random point.
# [0.002631058751802242, 7, 2, 0.8094065591181088, 0.6564247612511152, 203]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9927573719606829
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 1.4126
# Function value obtained: -0.6004
# Current minimum: -0.6004
# Iteration No: 8 started. Evaluating function at random point.
# [0.029467841862682993, 12, 15, 0.827012524988553, 0.6351236738784994, 429]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9885652104108319
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 6.6346
# Function value obtained: -0.4998
# Current minimum: -0.6004
# Iteration No: 9 started. Evaluating function at random point.
# [0.0286302622574232, 13, 2, 0.2696716259957565, 0.32867653855643914, 216]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9879765238953209
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 7.7080
# Function value obtained: -0.5071
# Current minimum: -0.6004
# Iteration No: 10 started. Evaluating function at random point.
# [0.07290106109067848, 7, 18, 0.3757619100661938, 0.5580911933360774, 928]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9853363540681807
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 2.1118
# Function value obtained: -0.4478
# Current minimum: -0.6004
# Iteration No: 11 started. Evaluating function at random point.
# [0.032154409360075596, 15, 5, 0.5647106141713536, 0.3681750407717019, 761]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9873164814385358
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 29.1255
# Function value obtained: -0.4825
# Current minimum: -0.6004
# Iteration No: 12 started. Evaluating function at random point.
# [0.008634896688306491, 5, 16, 0.7254317405645737, 0.5498740423000136, 324]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.99099131241415
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 0.7565
# Function value obtained: -0.5472
# Current minimum: -0.6004
# Iteration No: 13 started. Evaluating function at random point.
# [0.015980565008053914, 2, 14, 0.11096489128053799, 0.6410203632791965, 432]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9828924130795441
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 0.2744
# Function value obtained: -0.5101
# Current minimum: -0.6004
# Iteration No: 14 started. Evaluating function at random point.
# [0.011550204958577216, 5, 2, 0.512918493685699, 0.7739136326608949, 203]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9901528801041797
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 1.1463
# Function value obtained: -0.5228
# Current minimum: -0.6004
# Iteration No: 15 started. Evaluating function at random point.
# [0.0012163988792049526, 5, 8, 0.6258634623492736, 0.2408825706715303, 834]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9869240237615284
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 4.7468
# Function value obtained: -0.5238
# Current minimum: -0.6004
# Iteration No: 16 started. Evaluating function at random point.
# [0.0017144370993914888, 15, 20, 0.37348077501045734, 0.17244478533885504, 695]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.96384037675937
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 14.2608
# Function value obtained: -0.3396
# Current minimum: -0.6004
# Iteration No: 17 started. Evaluating function at random point.
# [0.009572804509496956, 3, 16, 0.3681196764732623, 0.09702530628585843, 982]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9855504218920027
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 1.1100
# Function value obtained: -0.4735
# Current minimum: -0.6004
# Iteration No: 18 started. Evaluating function at random point.
# [0.014522930049668745, 2, 12, 0.3762386276600308, 0.8958853719155146, 636]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9910805073407425
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 0.4463
# Function value obtained: -0.5393
# Current minimum: -0.6004
# Iteration No: 19 started. Evaluating function at random point.
# [0.03794278058906573, 1, 13, 0.15198136859732872, 0.5129274712241312, 849]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.976345505467649
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 0.5944
# Function value obtained: -0.4281
# Current minimum: -0.6004
# Iteration No: 20 started. Evaluating function at random point.
# [0.001639641980958233, 15, 2, 0.5213788276432161, 0.1428101274280686, 585]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9306955420375689
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 56.9007
# Function value obtained: -0.2969
# Current minimum: -0.6004
# Iteration No: 21 started. Searching for the next optimal point.
# [0.0010783730467021774, 14, 3, 0.9568473748336751, 0.6161114795042427, 109]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9905274987958684
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 23.2465
# Function value obtained: -0.5438
# Current minimum: -0.6004
# Iteration No: 22 started. Searching for the next optimal point.
# [0.0010074262120949838, 15, 1, 0.9953973056770764, 0.8303214420318197, 180]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9889219901172022
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 88.5007
# Function value obtained: -0.5524
# Current minimum: -0.6004
# Iteration No: 23 started. Searching for the next optimal point.
# [0.0019478661176101132, 15, 2, 0.8727238387295322, 0.2672972736391587, 234]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9770055479244341
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 45.2503
# Function value obtained: -0.4415
# Current minimum: -0.6004
# Iteration No: 24 started. Searching for the next optimal point.
# [0.0018848192931234138, 6, 1, 0.970249830024789, 0.19249550302169244, 166]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9844800827728919
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 0.9856
# Function value obtained: -0.5209
# Current minimum: -0.6004
# Iteration No: 25 started. Searching for the next optimal point.
# [0.002446265395622445, 15, 4, 0.3987826111246588, 0.9262775054905162, 504]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9916335158856164
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 38.7612
# Function value obtained: -0.5410
# Current minimum: -0.6004
# Iteration No: 26 started. Searching for the next optimal point.
# [0.001397556318354499, 14, 2, 0.555115242367112, 0.6825355432905279, 491]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9911340242966981
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 50.9110
# Function value obtained: -0.5336
# Current minimum: -0.6004
# Iteration No: 27 started. Searching for the next optimal point.
# [0.002548090655455449, 15, 2, 0.9555089243144069, 0.5205685325177798, 673]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9909377954581944
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 130.5340
# Function value obtained: -0.5449
# Current minimum: -0.6004
# Iteration No: 28 started. Searching for the next optimal point.
# [0.0019523017911823053, 15, 3, 0.5236059473103251, 0.5853671512347286, 126]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.99050965981055
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 12.6682
# Function value obtained: -0.5333
# Current minimum: -0.6004
# Iteration No: 29 started. Searching for the next optimal point.
# [0.001323717044593777, 15, 2, 0.5970094980904228, 0.462764886736986, 217]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9896890664858983
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 30.4677
# Function value obtained: -0.5184
# Current minimum: -0.6004
# Iteration No: 30 started. Searching for the next optimal point.
# [0.0023862552929930112, 10, 9, 0.9807757675132954, 0.14333503158413313, 691]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9784683447205523
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 5.7992
# Function value obtained: -0.4053
# Current minimum: -0.6004
# Iteration No: 31 started. Searching for the next optimal point.
# [0.02433527939366772, 8, 2, 0.8158852810570392, 0.1147461939611248, 153]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9610039780937261
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 1.1169
# Function value obtained: -0.3993
# Current minimum: -0.6004
# Iteration No: 32 started. Searching for the next optimal point.
# [0.0014154281192295677, 15, 1, 0.5105314546589234, 0.39804224311127984, 628]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9865850830404767
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 143.4355
# Function value obtained: -0.4897
# Current minimum: -0.6004
# Iteration No: 33 started. Searching for the next optimal point.
# [0.0011136669353083038, 7, 16, 0.899320033959323, 0.5231339292551856, 132]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9915264819737053
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 1.0513
# Function value obtained: -0.5818
# Current minimum: -0.6004
# Iteration No: 34 started. Searching for the next optimal point.
# [0.0016097657588266755, 8, 13, 0.8473102440176224, 0.4376298131824492, 207]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9879230069393653
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 1.9541
# Function value obtained: -0.5187
# Current minimum: -0.6004
# Iteration No: 35 started. Searching for the next optimal point.
# [0.0011653338654928989, 7, 17, 0.4158926350919989, 0.23067188624028861, 130]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9807338958560037
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 0.9443
# Function value obtained: -0.4175
# Current minimum: -0.6004
# Iteration No: 36 started. Searching for the next optimal point.
# [0.0014001656934584873, 8, 17, 0.9298283107733978, 0.537411473902631, 203]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9907772445903277
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 2.0995
# Function value obtained: -0.5326
# Current minimum: -0.6004
# Iteration No: 37 started. Searching for the next optimal point.
# [0.0010229072464660511, 4, 18, 0.9437245959286483, 0.5262697051512377, 948]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9862461423194249
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 1.8157
# Function value obtained: -0.5548
# Current minimum: -0.6004
# Iteration No: 38 started. Searching for the next optimal point.
# [0.001189957060101376, 3, 20, 0.46972886424185006, 0.5933309364535859, 257]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9853720320388176
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 0.5678
# Function value obtained: -0.5193
# Current minimum: -0.6004
# Iteration No: 39 started. Searching for the next optimal point.
# [0.0023638426573222276, 15, 17, 0.9332901080218421, 0.30886028052499565, 806]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9834632606097364
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 29.8810
# Function value obtained: -0.4473
# Current minimum: -0.6004
# Iteration No: 40 started. Searching for the next optimal point.
# [0.052230781852609785, 7, 3, 0.7945905830448365, 0.6541153747534154, 213]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9900993631482242
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 1.4538
# Function value obtained: -0.5539
# Current minimum: -0.6004
# Iteration No: 41 started. Searching for the next optimal point.
# [0.048107805166015385, 7, 6, 0.8155178197846928, 0.6744484841716512, 235]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9893322867795279
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 1.2998
# Function value obtained: -0.5366
# Current minimum: -0.6004
# Iteration No: 42 started. Searching for the next optimal point.
# [0.005973787410034742, 4, 2, 0.8279653835161968, 0.4825418399511872, 112]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9906345327077796
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 0.5488
# Function value obtained: -0.5912
# Current minimum: -0.6004
# Iteration No: 43 started. Searching for the next optimal point.
# [0.0019583570383477408, 2, 3, 0.8076623531085168, 0.37055562970304595, 131]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.982027222291596
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 0.4518
# Function value obtained: -0.5081
# Current minimum: -0.6004
# Iteration No: 44 started. Searching for the next optimal point.
# [0.005025740614813507, 8, 2, 0.81674595940333, 0.48405911394581164, 166]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9917405497975275
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 2.9389
# Function value obtained: -0.5832
# Current minimum: -0.6004
# Iteration No: 45 started. Searching for the next optimal point.
# [0.04325253292312285, 6, 1, 0.8733142434802618, 0.49616242280423845, 129]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9918654226947572
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 1.0605
# Function value obtained: -0.5852
# Current minimum: -0.6004
# Iteration No: 46 started. Searching for the next optimal point.
# [0.03707708413766464, 4, 2, 0.7512985827672742, 0.6795662574460258, 110]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9908931979948981
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 0.5151
# Function value obtained: -0.5383
# Current minimum: -0.6004
# Iteration No: 47 started. Searching for the next optimal point.
# [0.0018224771200543665, 8, 2, 0.8788218331546306, 0.44533712792319674, 149]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9914551260324312
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 1.7875
# Function value obtained: -0.5987
# Current minimum: -0.6004
# Iteration No: 48 started. Searching for the next optimal point.
# [0.010254091866978798, 11, 2, 0.8054778894265147, 0.47480238608850994, 128]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9908664395169202
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 5.8992
# Function value obtained: -0.5601
# Current minimum: -0.6004
# Iteration No: 49 started. Searching for the next optimal point.
# [0.0040842067844086985, 7, 2, 0.8526719996207444, 0.44540860959335277, 141]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9919367786360312
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 1.2347
# Function value obtained: -0.5802
# Current minimum: -0.6004
# Iteration No: 50 started. Searching for the next optimal point.
# [0.008982779387053582, 8, 1, 0.7721863695812392, 0.4249577034658381, 141]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.9899744902509945
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 2.0413
# Function value obtained: -0.5593
# Current minimum: -0.6004

# %%
res.x
# Out:
# [0.002631058751802242, 7, 2, 0.8094065591181088, 0.6564247612511152, 203]

# %%
lgbm = LGBMClassifier(learning_rate=0.002631058751802242, num_leaves=2**7, max_depth=7,
                      min_child_samples=2, subsample=0.8094065591181088, colsample_bytree=0.6564247612511152,
                      n_estimators=203, random_state=75, class_weight="balanced", n_jobs=6)
lgbm.fit(X_train_feat, y_train)
ypred_lgbm = lgbm.predict_proba(X_test_feat)[:,1]

# %%
print('average precision score: {}'.format(average_precision_score(y_test, ypred_lgbm)))
print('roc_auc_scode: {}'.format(roc_auc_score(y_test, ypred_lgbm)))
print('log loss: {}'.format(log_loss(y_test, ypred_lgbm)))
# Out:
# average precision score: 0.5763678266484014
# roc_auc_scode: 0.992864405872594
# log loss: 0.3765352518715935

# %% [markdown]
# <a name='ENSEN'></a>
# <h3>Ensemble</h3>

# %%
vot = VotingClassifier(estimators=[('lr', lr), ('rf', rf), ('lgbm', lgbm)], voting='soft')
vot.fit(X_train_feat, y_train)
ypred_vot = vot.predict_proba(X_test_feat)[:,1]

# %%
print('average precision score: {}'.format(average_precision_score(y_test, ypred_vot)))
print('roc_auc_scode: {}'.format(roc_auc_score(y_test, ypred_vot)))
print('log loss: {}'.format(log_loss(y_test, ypred_vot)))
# Out:
# average precision score: 0.5432782433600254
# roc_auc_scode: 0.9892430918529355
# log loss: 0.14067055868961295

# %%
lr_perc = 0.0
rf_perc = 0.5
lgbm_perc = 0.5
ypred_ens = lr_perc*ypred_lr + rf_perc*ypred_rf + lgbm_perc*ypred_lgbm
print('average precision score: {}'.format(average_precision_score(y_test, ypred_ens)))
print('roc_auc_scode: {}'.format(roc_auc_score(y_test, ypred_ens)))
print('log loss: {}'.format(log_loss(y_test, ypred_ens)))
# Out:
# average precision score: 0.5794405144412936
# roc_auc_scode: 0.9919367786360311
# log loss: 0.19835566252934994

# %% [markdown]
# <a name='SAV'></a>
# <h2>Salvando os modelos</h2>

# %%
jb.dump(lgbm, "./deploy/lgbm_20211028.pkl.z")
jb.dump(rf, "./deploy/random_forest_20211028.pkl.z")
jb.dump(enc, "./deploy/onehotvec_20211028.pkl.z")
# Out:
# ['./deploy/onehotvec_20211028.pkl.z']

# %%
teste = X_test.copy()
teste['proba'] = ypred_ens
df_teste = pd.read_csv('apartamentos.csv')
teste = teste.merge(df_teste, how='left', left_index=True, right_index=True)
teste.sort_values('proba', ascending=False)[['id', 'quartos_x', 'area_x', 'custo_x', 'mobiliado_x',
                                             'estacao_x', 'distancia_x', 'proba', 'apartment_link']]
# Out:
#              id  quartos_x  area_x  custo_x  mobiliado_x  \
# 5408  893439730          1      40     1907            0
# 5207  893439739          1      40     2285            0
# 492   893437823          1      50     2397            0
# 867   893252861          1      36     2488            0
# 350   892874927          1      52     2602            0
# ...         ...        ...     ...      ...          ...
# 3832  893000385          3      64     4153            0
# 5153  893420041          2      81     3442            0
# 4563  893235837          3      78     4918            0
# 3665  893414336          3      68     5444            1
# 3010  893251049          3      82     4747            0
#
#                   estacao_x  distancia_x     proba  \
# 5408        Japao Liberdade         0.37  0.826700
# 5207        Japao Liberdade         0.37  0.809185
# 492            Trianon Masp         0.40  0.796379
# 867               Vergueiro         0.49  0.796055
# 350              Consolacao         0.36  0.792344
# ...                     ...          ...       ...
# 3832  Palmeiras Barra Funda         1.53  0.146360
# 5153               Pedro II         1.08  0.146360
# 4563       Marechal Deodoro         0.30  0.146359
# 3665  Palmeiras Barra Funda         1.50  0.146359
# 3010               Pedro II         1.38  0.146326
#
#                                        apartment_link
# 5408  https://www.quintoandar.com.br/imovel/893439730
# 5207  https://www.quintoandar.com.br/imovel/893439739
# 492   https://www.quintoandar.com.br/imovel/893437823
# 867   https://www.quintoandar.com.br/imovel/893252861
# 350   https://www.quintoandar.com.br/imovel/892874927
# ...                                               ...
# 3832  https://www.quintoandar.com.br/imovel/893000385
# 5153  https://www.quintoandar.com.br/imovel/893420041
# 4563  https://www.quintoandar.com.br/imovel/893235837
# 3665  https://www.quintoandar.com.br/imovel/893414336
# 3010  https://www.quintoandar.com.br/imovel/893251049
#
# [1962 rows x 9 columns]
